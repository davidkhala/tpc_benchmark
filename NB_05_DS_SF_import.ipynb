# %% [markdown]
# ## TPC Dataset Import
# Import data for TPC test from GCS into Snowflake database

# %% [markdown]
# ### Set Configs

# %%
import config, sf, datetime

# In "Dry Run" mode we generate and print SQL queries but not run them.
# You can manually run them in "workbench" if you want
DRY_RUN = False
TEST = sf.TEST_DS  # we want to run TPC-DS
SIZE = '1000GB'  # dataset size to use in test

# %% [markdown]
# `Note: that we use configuration data from config.py`

# %% [markdown]
# ### Start Snowflake WAREHOUSE

# %%
# initiate SnowflakeHelper with Test type and dataset size specified
sf_helper = sf.SnowflakeHelper(TEST, SIZE, config)

# start Warehouse
sf_helper.warehouse_start()
# Out:
# preparing to open connection to Snowflake
# using config: user:dauren, pass: 239nj8834uffe, account: wja13212
# connection opened
# running query: USE ROLE ACCOUNTADMIN
# result: Statement executed successfully.
# running query: ALTER WAREHOUSE TEST1 RESUME;
# warehouse start: Statement executed successfully.
# running query: USE WAREHOUSE TEST1
# result: Statement executed successfully.
# running query: CREATE DATABASE IF NOT EXISTS ds_1000GB
# result: Database DS_1000GB successfully created.
# running query: USE DATABASE ds_1000GB
# result: Statement executed successfully.

# %% [markdown]
# ### Setup STAGE: Link to GCS data source and stages files for uploading

# %%
if not sf_helper.is_integrated():
    # integrate Snoflake with GCS.
    integration_id = sf_helper.create_integration(is_dry_run=DRY_RUN)
    print(f'integrated with gcs: {integration_id}')
# Out:
# --creating named file format: "@csv_file_format"
# running query: create or replace file format csv_file_format
#             type = csv
#             field_delimiter = '|'
#             skip_header = 1
#             null_if = ('NULL', 'null')
#             empty_field_as_null = true
#             encoding = 'iso-8859-1'
#             compression = none;
# result File format CSV_FILE_FORMAT successfully created.
#
#
# --done creating named file format
#
#
# --integrating "gcs_ds_1000GB_integration" ...
#
#
# --creating storage integration: "gcs_ds_1000GB_integration"
# running query: CREATE STORAGE INTEGRATION gcs_ds_1000GB_integration TYPE=EXTERNAL_STAGE STORAGE_PROVIDER=GCS ENABLED=TRUE STORAGE_ALLOWED_LOCATIONS=('gcs://tpc-benchmark-5947/');
# result Integration GCS_DS_1000GB_INTEGRATION successfully created.
#
#
# --finished creating storage integration
# running query: GRANT CREATE STAGE on schema public to ROLE ACCOUNTADMIN;
# result Statement executed successfully.
# running query: GRANT USAGE on INTEGRATION gcs_ds_1000GB_integration to ROLE ACCOUNTADMIN;
# result Statement executed successfully.
# running query: CREATE STAGE gcs_ds_1000GB_integration_stage URL='gcs://tpc-benchmark-5947' STORAGE_INTEGRATION=gcs_ds_1000GB_integration FILE_FORMAT=csv_file_format;
# result Stage area GCS_DS_1000GB_INTEGRATION_STAGE successfully created.
# running query: list  @gcs_ds_1000GB_integration_stage;
# result gcs://tpc-benchmark-5947/_data_ds_1000GB_catalog_returns_15_96.dat
# --finished staging "gcs_ds_1000GB_integration"
#
#
# integrated with gcs: gcs_ds_1000GB_integration

# %% [markdown]
# ### Test STAGE

# %%
db_files = sf_helper.list_integration(integration_id)
for table, files in db_files.items():
    print(f'{table}:')
    for file in files:
        print(f'\t{file}')
    print(f'\tmissing {sf_helper.gcs_file_range - len(files)} files\n\n')
# Out:
# --listing stage: "@gcs_ds_1000GB_integration_stage"
# unknown table!!!! gcs://tpc-benchmark-5947/ds_1000GB_date_dim_1_96.dat
# unknown table!!!! gcs://tpc-benchmark-5947/ds_1000GB_dbgen_version_1_96.dat
# unknown table!!!! gcs://tpc-benchmark-5947/ds_1000GB_warehouse_1_96.dat
#
#
# --done listing stage
# call_center:
# 	gcs://tpc-benchmark-5947/ds_1000GB_call_center_1_96.dat
# 	missing 95 files
#
#
# catalog_page:
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_page_1_96.dat
# 	missing 95 files
#
#
# catalog_returns:
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_10_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_11_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_12_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_13_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_14_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_15_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_16_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_17_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_18_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_19_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_1_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_20_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_21_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_22_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_23_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_24_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_25_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_26_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_27_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_28_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_29_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_2_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_30_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_31_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_32_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_33_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_34_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_35_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_36_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_37_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_38_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_39_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_3_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_40_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_41_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_42_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_43_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_44_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_45_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_46_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_47_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_48_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_49_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_4_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_50_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_51_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_52_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_53_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_54_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_55_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_56_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_57_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_58_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_59_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_5_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_60_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_61_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_62_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_63_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_64_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_65_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_66_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_67_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_68_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_69_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_6_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_70_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_71_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_72_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_73_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_74_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_75_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_76_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_77_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_78_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_79_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_7_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_80_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_81_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_82_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_83_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_84_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_85_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_86_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_87_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_88_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_89_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_8_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_90_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_91_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_92_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_93_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_94_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_95_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_96_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_9_96.dat
# 	missing 0 files
#
#
# catalog_sales:
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_10_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_11_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_12_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_13_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_14_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_15_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_16_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_17_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_18_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_19_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_1_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_20_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_21_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_22_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_23_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_24_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_25_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_26_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_27_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_28_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_29_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_2_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_30_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_31_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_32_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_33_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_34_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_35_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_36_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_37_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_38_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_39_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_3_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_40_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_41_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_42_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_43_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_44_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_45_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_46_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_47_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_48_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_49_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_4_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_50_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_51_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_52_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_53_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_54_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_55_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_56_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_57_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_58_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_59_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_5_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_60_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_61_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_62_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_63_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_64_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_65_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_66_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_67_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_68_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_69_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_6_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_70_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_71_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_72_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_73_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_74_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_75_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_76_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_77_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_78_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_79_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_7_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_80_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_81_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_82_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_83_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_84_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_85_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_86_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_87_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_88_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_89_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_8_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_90_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_91_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_92_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_93_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_94_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_95_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_96_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_9_96.dat
# 	missing 0 files
#
#
# customer:
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_10_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_11_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_12_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_13_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_14_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_15_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_16_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_17_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_18_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_19_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_1_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_20_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_21_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_22_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_23_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_24_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_25_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_26_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_27_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_28_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_29_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_2_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_30_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_31_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_32_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_33_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_34_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_35_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_36_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_37_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_38_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_39_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_3_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_40_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_41_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_42_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_43_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_44_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_45_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_46_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_47_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_48_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_49_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_4_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_50_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_51_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_52_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_53_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_54_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_55_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_56_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_57_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_58_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_59_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_5_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_60_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_61_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_62_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_63_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_64_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_65_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_66_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_67_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_68_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_69_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_6_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_70_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_71_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_72_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_73_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_74_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_75_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_76_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_77_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_78_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_79_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_7_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_80_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_81_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_82_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_83_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_84_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_85_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_86_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_87_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_88_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_89_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_8_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_90_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_91_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_92_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_93_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_94_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_95_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_96_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_9_96.dat
# 	missing 0 files
#
#
# customer_address:
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_10_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_11_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_12_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_13_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_14_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_15_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_16_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_17_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_18_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_19_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_1_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_20_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_21_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_22_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_23_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_24_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_25_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_26_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_27_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_28_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_29_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_2_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_30_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_31_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_32_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_33_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_34_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_35_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_36_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_37_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_38_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_39_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_3_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_40_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_41_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_42_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_43_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_44_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_45_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_46_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_47_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_48_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_49_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_4_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_50_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_51_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_52_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_53_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_54_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_55_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_56_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_57_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_58_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_59_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_5_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_60_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_61_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_62_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_63_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_64_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_65_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_66_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_67_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_68_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_69_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_6_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_70_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_71_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_72_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_73_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_74_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_75_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_76_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_77_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_78_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_79_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_7_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_80_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_81_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_82_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_83_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_84_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_85_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_86_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_87_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_88_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_89_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_8_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_90_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_91_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_92_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_93_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_94_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_95_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_96_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_address_9_96.dat
# 	missing 0 files
#
#
# customer_demographics:
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_10_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_11_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_12_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_13_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_14_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_15_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_16_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_17_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_18_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_19_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_1_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_20_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_21_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_22_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_23_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_24_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_25_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_26_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_27_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_28_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_29_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_2_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_30_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_31_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_32_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_33_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_34_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_35_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_36_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_37_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_38_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_39_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_3_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_40_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_41_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_42_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_43_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_44_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_45_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_46_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_47_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_48_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_49_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_4_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_50_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_51_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_52_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_53_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_54_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_55_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_56_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_57_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_58_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_59_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_5_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_60_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_61_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_62_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_63_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_64_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_65_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_66_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_67_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_68_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_69_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_6_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_70_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_71_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_72_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_73_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_74_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_75_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_76_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_77_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_78_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_79_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_7_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_80_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_81_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_82_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_83_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_84_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_85_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_86_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_87_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_88_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_89_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_8_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_90_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_91_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_92_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_93_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_94_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_95_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_96_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_customer_demographics_9_96.dat
# 	missing 0 files
#
#
# household_demographics:
# 	gcs://tpc-benchmark-5947/ds_1000GB_household_demographics_1_96.dat
# 	missing 95 files
#
#
# income_band:
# 	gcs://tpc-benchmark-5947/ds_1000GB_income_band_1_96.dat
# 	missing 95 files
#
#
# inventory:
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_10_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_11_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_12_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_13_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_14_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_15_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_16_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_17_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_18_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_19_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_1_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_20_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_21_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_22_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_23_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_24_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_25_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_26_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_27_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_28_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_29_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_2_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_30_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_31_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_32_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_33_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_34_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_35_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_36_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_37_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_38_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_39_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_3_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_40_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_41_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_42_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_43_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_44_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_45_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_46_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_47_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_48_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_49_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_4_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_50_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_51_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_52_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_53_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_54_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_55_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_56_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_57_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_58_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_59_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_5_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_60_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_61_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_62_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_63_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_64_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_65_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_66_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_67_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_68_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_69_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_6_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_70_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_71_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_72_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_73_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_74_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_75_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_76_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_77_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_78_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_79_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_7_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_80_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_81_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_82_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_83_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_84_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_85_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_86_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_87_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_88_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_89_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_8_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_90_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_91_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_92_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_93_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_94_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_95_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_96_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_inventory_9_96.dat
# 	missing 0 files
#
#
# item:
# 	gcs://tpc-benchmark-5947/ds_1000GB_item_1_96.dat
# 	missing 95 files
#
#
# promotion:
# 	gcs://tpc-benchmark-5947/ds_1000GB_promotion_1_96.dat
# 	missing 95 files
#
#
# reason:
# 	gcs://tpc-benchmark-5947/ds_1000GB_reason_1_96.dat
# 	missing 95 files
#
#
# ship_mode:
# 	gcs://tpc-benchmark-5947/ds_1000GB_ship_mode_1_96.dat
# 	missing 95 files
#
#
# store:
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_1_96.dat
# 	missing 95 files
#
#
# store_returns:
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_10_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_11_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_12_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_13_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_14_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_15_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_16_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_17_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_18_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_19_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_1_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_20_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_21_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_22_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_23_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_24_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_25_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_26_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_27_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_28_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_29_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_2_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_30_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_31_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_32_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_33_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_34_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_35_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_36_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_37_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_38_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_39_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_3_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_40_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_41_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_42_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_43_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_44_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_45_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_46_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_47_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_48_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_49_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_4_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_50_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_51_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_52_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_53_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_54_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_55_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_56_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_57_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_58_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_59_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_5_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_60_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_61_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_62_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_63_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_64_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_65_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_66_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_67_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_68_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_69_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_6_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_70_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_71_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_72_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_73_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_74_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_75_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_76_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_77_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_78_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_79_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_7_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_80_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_81_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_82_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_83_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_84_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_85_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_86_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_87_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_88_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_89_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_8_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_90_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_91_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_92_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_93_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_94_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_95_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_96_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_returns_9_96.dat
# 	missing 0 files
#
#
# store_sales:
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_10_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_11_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_12_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_13_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_14_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_15_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_16_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_17_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_18_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_19_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_1_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_20_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_21_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_22_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_23_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_24_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_25_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_26_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_27_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_28_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_29_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_2_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_30_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_31_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_32_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_33_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_34_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_35_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_36_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_37_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_38_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_39_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_3_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_40_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_41_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_42_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_43_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_44_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_45_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_46_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_47_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_48_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_49_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_4_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_50_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_51_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_52_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_53_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_54_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_55_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_56_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_57_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_58_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_59_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_5_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_60_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_61_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_62_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_63_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_64_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_65_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_66_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_67_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_68_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_69_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_6_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_70_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_71_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_72_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_73_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_74_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_75_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_76_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_77_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_78_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_79_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_7_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_80_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_81_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_82_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_83_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_84_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_85_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_86_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_87_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_88_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_89_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_8_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_90_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_91_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_92_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_93_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_94_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_95_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_96_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_store_sales_9_96.dat
# 	missing 0 files
#
#
# time_dim:
# 	gcs://tpc-benchmark-5947/ds_1000GB_time_dim_1_96.dat
# 	missing 95 files
#
#
# web_page:
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_page_1_96.dat
# 	missing 95 files
#
#
# web_returns:
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_10_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_11_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_12_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_13_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_14_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_15_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_16_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_17_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_18_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_19_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_1_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_20_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_21_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_22_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_23_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_24_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_25_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_26_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_27_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_28_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_29_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_2_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_30_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_31_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_32_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_33_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_34_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_35_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_36_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_37_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_38_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_39_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_3_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_40_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_41_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_42_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_43_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_44_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_45_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_46_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_47_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_48_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_49_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_4_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_50_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_51_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_52_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_53_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_54_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_55_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_56_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_57_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_58_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_59_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_5_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_60_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_61_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_62_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_63_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_64_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_65_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_66_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_67_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_68_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_69_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_6_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_70_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_71_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_72_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_73_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_74_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_75_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_76_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_77_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_78_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_79_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_7_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_80_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_81_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_82_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_83_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_84_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_85_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_86_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_87_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_88_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_89_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_8_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_90_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_91_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_92_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_93_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_94_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_95_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_96_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_returns_9_96.dat
# 	missing 0 files
#
#
# web_sales:
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_10_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_11_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_12_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_13_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_14_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_15_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_16_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_17_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_18_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_19_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_1_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_20_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_21_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_22_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_23_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_24_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_25_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_26_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_27_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_28_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_29_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_2_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_30_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_31_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_32_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_33_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_34_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_35_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_36_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_37_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_38_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_39_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_3_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_40_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_41_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_42_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_43_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_44_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_45_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_46_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_47_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_48_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_49_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_4_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_50_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_51_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_52_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_53_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_54_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_55_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_56_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_57_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_58_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_59_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_5_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_60_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_61_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_62_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_63_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_64_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_65_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_66_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_67_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_68_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_69_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_6_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_70_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_71_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_72_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_73_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_74_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_75_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_76_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_77_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_78_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_79_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_7_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_80_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_81_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_82_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_83_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_84_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_85_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_86_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_87_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_88_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_89_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_8_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_90_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_91_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_92_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_93_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_94_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_95_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_96_96.dat
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_sales_9_96.dat
# 	missing 0 files
#
#
# web_site:
# 	gcs://tpc-benchmark-5947/ds_1000GB_web_site_1_96.dat
# 	missing 95 files

# %% [markdown]
# ### Create tables in Snowflake if needed

# %%
if not sf_helper.is_integrated():
    sf_helper.create_schema(is_dry_run=DRY_RUN)
# Out:
# --pushing schema: "/home/vagrant/bq_snowflake_benchmark/h/2.18.0_rc2/dbgen/dss.ddl"
# running query: --
# -- Legal Notice
# --
# -- This document and associated source code (the "Work") is a part of a
# -- benchmark specification maintained by the TPC.
# --
# -- The TPC reserves all right, title, and interest to the Work as provided
# -- under U.S. and international laws, including without limitation all patent
# -- and trademark rights therein.
# --
# -- No Warranty
# --
# -- 1.1 TO THE MAXIMUM EXTENT PERMITTED BY APPLICABLE LAW, THE INFORMATION
# --     CONTAINED HEREIN IS PROVIDED "AS IS" AND WITH ALL FAULTS, AND THE
# --     AUTHORS AND DEVELOPERS OF THE WORK HEREBY DISCLAIM ALL OTHER
# --     WARRANTIES AND CONDITIONS, EITHER EXPRESS, IMPLIED OR STATUTORY,
# --     INCLUDING, BUT NOT LIMITED TO, ANY (IF ANY) IMPLIED WARRANTIES,
# --     DUTIES OR CONDITIONS OF MERCHANTABILITY, OF FITNESS FOR A PARTICULAR
# --     PURPOSE, OF ACCURACY OR COMPLETENESS OF RESPONSES, OF RESULTS, OF
# --     WORKMANLIKE EFFORT, OF LACK OF VIRUSES, AND OF LACK OF NEGLIGENCE.
# --     ALSO, THERE IS NO WARRANTY OR CONDITION OF TITLE, QUIET ENJOYMENT,
# --     QUIET POSSESSION, CORRESPONDENCE TO DESCRIPTION OR NON-INFRINGEMENT
# --     WITH REGARD TO THE WORK.
# -- 1.2 IN NO EVENT WILL ANY AUTHOR OR DEVELOPER OF THE WORK BE LIABLE TO
# --     ANY OTHER PARTY FOR ANY DAMAGES, INCLUDING BUT NOT LIMITED TO THE
# --     COST OF PROCURING SUBSTITUTE GOODS OR SERVICES, LOST PROFITS, LOSS
# --     OF USE, LOSS OF DATA, OR ANY INCIDENTAL, CONSEQUENTIAL, DIRECT,
# --     INDIRECT, OR SPECIAL DAMAGES WHETHER UNDER CONTRACT, TORT, WARRANTY,
# --     OR OTHERWISE, ARISING IN ANY WAY OUT OF THIS OR ANY OTHER AGREEMENT
# --     RELATING TO THE WORK, WHETHER OR NOT SUCH AUTHOR OR DEVELOPER HAD
# --     ADVANCE NOTICE OF THE POSSIBILITY OF SUCH DAMAGES.
# --
# -- Contributors:
# -- Gradient Systems
# --
# create table dbgen_version
# (
#     dv_version                varchar(16)                   ,
#     dv_create_date            date                          ,
#     dv_create_time            time                          ,
#     dv_cmdline_args           varchar(200)
# );
#
# result Table DBGEN_VERSION successfully created.
# running query:
# create table customer_address
# (
#     ca_address_sk             integer               not null,
#     ca_address_id             char(16)              not null,
#     ca_street_number          char(10)                      ,
#     ca_street_name            varchar(60)                   ,
#     ca_street_type            char(15)                      ,
#     ca_suite_number           char(10)                      ,
#     ca_city                   varchar(60)                   ,
#     ca_county                 varchar(30)                   ,
#     ca_state                  char(2)                       ,
#     ca_zip                    char(10)                      ,
#     ca_country                varchar(20)                   ,
#     ca_gmt_offset             decimal(5,2)                  ,
#     ca_location_type          char(20)                      ,
#     primary key (ca_address_sk)
# );
#
# result Table CUSTOMER_ADDRESS successfully created.
# running query:
# create table customer_demographics
# (
#     cd_demo_sk                integer               not null,
#     cd_gender                 char(1)                       ,
#     cd_marital_status         char(1)                       ,
#     cd_education_status       char(20)                      ,
#     cd_purchase_estimate      integer                       ,
#     cd_credit_rating          char(10)                      ,
#     cd_dep_count              integer                       ,
#     cd_dep_employed_count     integer                       ,
#     cd_dep_college_count      integer                       ,
#     primary key (cd_demo_sk)
# );
#
# result Table CUSTOMER_DEMOGRAPHICS successfully created.
# running query:
# create table date_dim
# (
#     d_date_sk                 integer               not null,
#     d_date_id                 char(16)              not null,
#     d_date                    date                          ,
#     d_month_seq               integer                       ,
#     d_week_seq                integer                       ,
#     d_quarter_seq             integer                       ,
#     d_year                    integer                       ,
#     d_dow                     integer                       ,
#     d_moy                     integer                       ,
#     d_dom                     integer                       ,
#     d_qoy                     integer                       ,
#     d_fy_year                 integer                       ,
#     d_fy_quarter_seq          integer                       ,
#     d_fy_week_seq             integer                       ,
#     d_day_name                char(9)                       ,
#     d_quarter_name            char(6)                       ,
#     d_holiday                 char(1)                       ,
#     d_weekend                 char(1)                       ,
#     d_following_holiday       char(1)                       ,
#     d_first_dom               integer                       ,
#     d_last_dom                integer                       ,
#     d_same_day_ly             integer                       ,
#     d_same_day_lq             integer                       ,
#     d_current_day             char(1)                       ,
#     d_current_week            char(1)                       ,
#     d_current_month           char(1)                       ,
#     d_current_quarter         char(1)                       ,
#     d_current_year            char(1)                       ,
#     primary key (d_date_sk)
# );
#
# result Table DATE_DIM successfully created.
# running query:
# create table warehouse
# (
#     w_warehouse_sk            integer               not null,
#     w_warehouse_id            char(16)              not null,
#     w_warehouse_name          varchar(20)                   ,
#     w_warehouse_sq_ft         integer                       ,
#     w_street_number           char(10)                      ,
#     w_street_name             varchar(60)                   ,
#     w_street_type             char(15)                      ,
#     w_suite_number            char(10)                      ,
#     w_city                    varchar(60)                   ,
#     w_county                  varchar(30)                   ,
#     w_state                   char(2)                       ,
#     w_zip                     char(10)                      ,
#     w_country                 varchar(20)                   ,
#     w_gmt_offset              decimal(5,2)                  ,
#     primary key (w_warehouse_sk)
# );
#
# result Table WAREHOUSE successfully created.
# running query:
# create table ship_mode
# (
#     sm_ship_mode_sk           integer               not null,
#     sm_ship_mode_id           char(16)              not null,
#     sm_type                   char(30)                      ,
#     sm_code                   char(10)                      ,
#     sm_carrier                char(20)                      ,
#     sm_contract               char(20)                      ,
#     primary key (sm_ship_mode_sk)
# );
#
# result Table SHIP_MODE successfully created.
# running query:
# create table time_dim
# (
#     t_time_sk                 integer               not null,
#     t_time_id                 char(16)              not null,
#     t_time                    integer                       ,
#     t_hour                    integer                       ,
#     t_minute                  integer                       ,
#     t_second                  integer                       ,
#     t_am_pm                   char(2)                       ,
#     t_shift                   char(20)                      ,
#     t_sub_shift               char(20)                      ,
#     t_meal_time               char(20)                      ,
#     primary key (t_time_sk)
# );
#
# result Table TIME_DIM successfully created.
# running query:
# create table reason
# (
#     r_reason_sk               integer               not null,
#     r_reason_id               char(16)              not null,
#     r_reason_desc             char(100)                     ,
#     primary key (r_reason_sk)
# );
#
# result Table REASON successfully created.
# running query:
# create table income_band
# (
#     ib_income_band_sk         integer               not null,
#     ib_lower_bound            integer                       ,
#     ib_upper_bound            integer                       ,
#     primary key (ib_income_band_sk)
# );
#
# result Table INCOME_BAND successfully created.
# running query:
# create table item
# (
#     i_item_sk                 integer               not null,
#     i_item_id                 char(16)              not null,
#     i_rec_start_date          date                          ,
#     i_rec_end_date            date                          ,
#     i_item_desc               varchar(200)                  ,
#     i_current_price           decimal(7,2)                  ,
#     i_wholesale_cost          decimal(7,2)                  ,
#     i_brand_id                integer                       ,
#     i_brand                   char(50)                      ,
#     i_class_id                integer                       ,
#     i_class                   char(50)                      ,
#     i_category_id             integer                       ,
#     i_category                char(50)                      ,
#     i_manufact_id             integer                       ,
#     i_manufact                char(50)                      ,
#     i_size                    char(20)                      ,
#     i_formulation             char(20)                      ,
#     i_color                   char(20)                      ,
#     i_units                   char(10)                      ,
#     i_container               char(10)                      ,
#     i_manager_id              integer                       ,
#     i_product_name            char(50)                      ,
#     primary key (i_item_sk)
# );
#
# result Table ITEM successfully created.
# running query:
# create table store
# (
#     s_store_sk                integer               not null,
#     s_store_id                char(16)              not null,
#     s_rec_start_date          date                          ,
#     s_rec_end_date            date                          ,
#     s_closed_date_sk          integer                       ,
#     s_store_name              varchar(50)                   ,
#     s_number_employees        integer                       ,
#     s_floor_space             integer                       ,
#     s_hours                   char(20)                      ,
#     s_manager                 varchar(40)                   ,
#     s_market_id               integer                       ,
#     s_geography_class         varchar(100)                  ,
#     s_market_desc             varchar(100)                  ,
#     s_market_manager          varchar(40)                   ,
#     s_division_id             integer                       ,
#     s_division_name           varchar(50)                   ,
#     s_company_id              integer                       ,
#     s_company_name            varchar(50)                   ,
#     s_street_number           varchar(10)                   ,
#     s_street_name             varchar(60)                   ,
#     s_street_type             char(15)                      ,
#     s_suite_number            char(10)                      ,
#     s_city                    varchar(60)                   ,
#     s_county                  varchar(30)                   ,
#     s_state                   char(2)                       ,
#     s_zip                     char(10)                      ,
#     s_country                 varchar(20)                   ,
#     s_gmt_offset              decimal(5,2)                  ,
#     s_tax_precentage          decimal(5,2)                  ,
#     primary key (s_store_sk)
# );
#
# result Table STORE successfully created.
# running query:
# create table call_center
# (
#     cc_call_center_sk         integer               not null,
#     cc_call_center_id         char(16)              not null,
#     cc_rec_start_date         date                          ,
#     cc_rec_end_date           date                          ,
#     cc_closed_date_sk         integer                       ,
#     cc_open_date_sk           integer                       ,
#     cc_name                   varchar(50)                   ,
#     cc_class                  varchar(50)                   ,
#     cc_employees              integer                       ,
#     cc_sq_ft                  integer                       ,
#     cc_hours                  char(20)                      ,
#     cc_manager                varchar(40)                   ,
#     cc_mkt_id                 integer                       ,
#     cc_mkt_class              char(50)                      ,
#     cc_mkt_desc               varchar(100)                  ,
#     cc_market_manager         varchar(40)                   ,
#     cc_division               integer                       ,
#     cc_division_name          varchar(50)                   ,
#     cc_company                integer                       ,
#     cc_company_name           char(50)                      ,
#     cc_street_number          char(10)                      ,
#     cc_street_name            varchar(60)                   ,
#     cc_street_type            char(15)                      ,
#     cc_suite_number           char(10)                      ,
#     cc_city                   varchar(60)                   ,
#     cc_county                 varchar(30)                   ,
#     cc_state                  char(2)                       ,
#     cc_zip                    char(10)                      ,
#     cc_country                varchar(20)                   ,
#     cc_gmt_offset             decimal(5,2)                  ,
#     cc_tax_percentage         decimal(5,2)                  ,
#     primary key (cc_call_center_sk)
# );
#
# result Table CALL_CENTER successfully created.
# running query:
# create table customer
# (
#     c_customer_sk             integer               not null,
#     c_customer_id             char(16)              not null,
#     c_current_cdemo_sk        integer                       ,
#     c_current_hdemo_sk        integer                       ,
#     c_current_addr_sk         integer                       ,
#     c_first_shipto_date_sk    integer                       ,
#     c_first_sales_date_sk     integer                       ,
#     c_salutation              char(10)                      ,
#     c_first_name              char(20)                      ,
#     c_last_name               char(30)                      ,
#     c_preferred_cust_flag     char(1)                       ,
#     c_birth_day               integer                       ,
#     c_birth_month             integer                       ,
#     c_birth_year              integer                       ,
#     c_birth_country           varchar(20)                   ,
#     c_login                   char(13)                      ,
#     c_email_address           char(50)                      ,
#     c_last_review_date        char(10)                      ,
#     primary key (c_customer_sk)
# );
#
# result Table CUSTOMER successfully created.
# running query:
# create table web_site
# (
#     web_site_sk               integer               not null,
#     web_site_id               char(16)              not null,
#     web_rec_start_date        date                          ,
#     web_rec_end_date          date                          ,
#     web_name                  varchar(50)                   ,
#     web_open_date_sk          integer                       ,
#     web_close_date_sk         integer                       ,
#     web_class                 varchar(50)                   ,
#     web_manager               varchar(40)                   ,
#     web_mkt_id                integer                       ,
#     web_mkt_class             varchar(50)                   ,
#     web_mkt_desc              varchar(100)                  ,
#     web_market_manager        varchar(40)                   ,
#     web_company_id            integer                       ,
#     web_company_name          char(50)                      ,
#     web_street_number         char(10)                      ,
#     web_street_name           varchar(60)                   ,
#     web_street_type           char(15)                      ,
#     web_suite_number          char(10)                      ,
#     web_city                  varchar(60)                   ,
#     web_county                varchar(30)                   ,
#     web_state                 char(2)                       ,
#     web_zip                   char(10)                      ,
#     web_country               varchar(20)                   ,
#     web_gmt_offset            decimal(5,2)                  ,
#     web_tax_percentage        decimal(5,2)                  ,
#     primary key (web_site_sk)
# );
#
# result Table WEB_SITE successfully created.
# running query:
# create table store_returns
# (
#     sr_returned_date_sk       integer                       ,
#     sr_return_time_sk         integer                       ,
#     sr_item_sk                integer               not null,
#     sr_customer_sk            integer                       ,
#     sr_cdemo_sk               integer                       ,
#     sr_hdemo_sk               integer                       ,
#     sr_addr_sk                integer                       ,
#     sr_store_sk               integer                       ,
#     sr_reason_sk              integer                       ,
#     sr_ticket_number          integer               not null,
#     sr_return_quantity        integer                       ,
#     sr_return_amt             decimal(7,2)                  ,
#     sr_return_tax             decimal(7,2)                  ,
#     sr_return_amt_inc_tax     decimal(7,2)                  ,
#     sr_fee                    decimal(7,2)                  ,
#     sr_return_ship_cost       decimal(7,2)                  ,
#     sr_refunded_cash          decimal(7,2)                  ,
#     sr_reversed_charge        decimal(7,2)                  ,
#     sr_store_credit           decimal(7,2)                  ,
#     sr_net_loss               decimal(7,2)                  ,
#     primary key (sr_item_sk, sr_ticket_number)
# );
#
# result Table STORE_RETURNS successfully created.
# running query:
# create table household_demographics
# (
#     hd_demo_sk                integer               not null,
#     hd_income_band_sk         integer                       ,
#     hd_buy_potential          char(15)                      ,
#     hd_dep_count              integer                       ,
#     hd_vehicle_count          integer                       ,
#     primary key (hd_demo_sk)
# );
#
# result Table HOUSEHOLD_DEMOGRAPHICS successfully created.
# running query:
# create table web_page
# (
#     wp_web_page_sk            integer               not null,
#     wp_web_page_id            char(16)              not null,
#     wp_rec_start_date         date                          ,
#     wp_rec_end_date           date                          ,
#     wp_creation_date_sk       integer                       ,
#     wp_access_date_sk         integer                       ,
#     wp_autogen_flag           char(1)                       ,
#     wp_customer_sk            integer                       ,
#     wp_url                    varchar(100)                  ,
#     wp_type                   char(50)                      ,
#     wp_char_count             integer                       ,
#     wp_link_count             integer                       ,
#     wp_image_count            integer                       ,
#     wp_max_ad_count           integer                       ,
#     primary key (wp_web_page_sk)
# );
#
# result Table WEB_PAGE successfully created.
# running query:
# create table promotion
# (
#     p_promo_sk                integer               not null,
#     p_promo_id                char(16)              not null,
#     p_start_date_sk           integer                       ,
#     p_end_date_sk             integer                       ,
#     p_item_sk                 integer                       ,
#     p_cost                    decimal(15,2)                 ,
#     p_response_target         integer                       ,
#     p_promo_name              char(50)                      ,
#     p_channel_dmail           char(1)                       ,
#     p_channel_email           char(1)                       ,
#     p_channel_catalog         char(1)                       ,
#     p_channel_tv              char(1)                       ,
#     p_channel_radio           char(1)                       ,
#     p_channel_press           char(1)                       ,
#     p_channel_event           char(1)                       ,
#     p_channel_demo            char(1)                       ,
#     p_channel_details         varchar(100)                  ,
#     p_purpose                 char(15)                      ,
#     p_discount_active         char(1)                       ,
#     primary key (p_promo_sk)
# );
#
# result Table PROMOTION successfully created.
# running query:
# create table catalog_page
# (
#     cp_catalog_page_sk        integer               not null,
#     cp_catalog_page_id        char(16)              not null,
#     cp_start_date_sk          integer                       ,
#     cp_end_date_sk            integer                       ,
#     cp_department             varchar(50)                   ,
#     cp_catalog_number         integer                       ,
#     cp_catalog_page_number    integer                       ,
#     cp_description            varchar(100)                  ,
#     cp_type                   varchar(100)                  ,
#     primary key (cp_catalog_page_sk)
# );
#
# result Table CATALOG_PAGE successfully created.
# running query:
# create table inventory
# (
#     inv_date_sk               integer               not null,
#     inv_item_sk               integer               not null,
#     inv_warehouse_sk          integer               not null,
#     inv_quantity_on_hand      integer                       ,
#     primary key (inv_date_sk, inv_item_sk, inv_warehouse_sk)
# );
#
# result Table INVENTORY successfully created.
# running query:
# create table catalog_returns
# (
#     cr_returned_date_sk       integer                       ,
#     cr_returned_time_sk       integer                       ,
#     cr_item_sk                integer               not null,
#     cr_refunded_customer_sk   integer                       ,
#     cr_refunded_cdemo_sk      integer                       ,
#     cr_refunded_hdemo_sk      integer                       ,
#     cr_refunded_addr_sk       integer                       ,
#     cr_returning_customer_sk  integer                       ,
#     cr_returning_cdemo_sk     integer                       ,
#     cr_returning_hdemo_sk     integer                       ,
#     cr_returning_addr_sk      integer                       ,
#     cr_call_center_sk         integer                       ,
#     cr_catalog_page_sk        integer                       ,
#     cr_ship_mode_sk           integer                       ,
#     cr_warehouse_sk           integer                       ,
#     cr_reason_sk              integer                       ,
#     cr_order_number           integer               not null,
#     cr_return_quantity        integer                       ,
#     cr_return_amount          decimal(7,2)                  ,
#     cr_return_tax             decimal(7,2)                  ,
#     cr_return_amt_inc_tax     decimal(7,2)                  ,
#     cr_fee                    decimal(7,2)                  ,
#     cr_return_ship_cost       decimal(7,2)                  ,
#     cr_refunded_cash          decimal(7,2)                  ,
#     cr_reversed_charge        decimal(7,2)                  ,
#     cr_store_credit           decimal(7,2)                  ,
#     cr_net_loss               decimal(7,2)                  ,
#     primary key (cr_item_sk, cr_order_number)
# );
#
# result Table CATALOG_RETURNS successfully created.
# running query:
# create table web_returns
# (
#     wr_returned_date_sk       integer                       ,
#     wr_returned_time_sk       integer                       ,
#     wr_item_sk                integer               not null,
#     wr_refunded_customer_sk   integer                       ,
#     wr_refunded_cdemo_sk      integer                       ,
#     wr_refunded_hdemo_sk      integer                       ,
#     wr_refunded_addr_sk       integer                       ,
#     wr_returning_customer_sk  integer                       ,
#     wr_returning_cdemo_sk     integer                       ,
#     wr_returning_hdemo_sk     integer                       ,
#     wr_returning_addr_sk      integer                       ,
#     wr_web_page_sk            integer                       ,
#     wr_reason_sk              integer                       ,
#     wr_order_number           integer               not null,
#     wr_return_quantity        integer                       ,
#     wr_return_amt             decimal(7,2)                  ,
#     wr_return_tax             decimal(7,2)                  ,
#     wr_return_amt_inc_tax     decimal(7,2)                  ,
#     wr_fee                    decimal(7,2)                  ,
#     wr_return_ship_cost       decimal(7,2)                  ,
#     wr_refunded_cash          decimal(7,2)                  ,
#     wr_reversed_charge        decimal(7,2)                  ,
#     wr_account_credit         decimal(7,2)                  ,
#     wr_net_loss               decimal(7,2)                  ,
#     primary key (wr_item_sk, wr_order_number)
# );
#
# result Table WEB_RETURNS successfully created.
# running query:
# create table web_sales
# (
#     ws_sold_date_sk           integer                       ,
#     ws_sold_time_sk           integer                       ,
#     ws_ship_date_sk           integer                       ,
#     ws_item_sk                integer               not null,
#     ws_bill_customer_sk       integer                       ,
#     ws_bill_cdemo_sk          integer                       ,
#     ws_bill_hdemo_sk          integer                       ,
#     ws_bill_addr_sk           integer                       ,
#     ws_ship_customer_sk       integer                       ,
#     ws_ship_cdemo_sk          integer                       ,
#     ws_ship_hdemo_sk          integer                       ,
#     ws_ship_addr_sk           integer                       ,
#     ws_web_page_sk            integer                       ,
#     ws_web_site_sk            integer                       ,
#     ws_ship_mode_sk           integer                       ,
#     ws_warehouse_sk           integer                       ,
#     ws_promo_sk               integer                       ,
#     ws_order_number           integer               not null,
#     ws_quantity               integer                       ,
#     ws_wholesale_cost         decimal(7,2)                  ,
#     ws_list_price             decimal(7,2)                  ,
#     ws_sales_price            decimal(7,2)                  ,
#     ws_ext_discount_amt       decimal(7,2)                  ,
#     ws_ext_sales_price        decimal(7,2)                  ,
#     ws_ext_wholesale_cost     decimal(7,2)                  ,
#     ws_ext_list_price         decimal(7,2)                  ,
#     ws_ext_tax                decimal(7,2)                  ,
#     ws_coupon_amt             decimal(7,2)                  ,
#     ws_ext_ship_cost          decimal(7,2)                  ,
#     ws_net_paid               decimal(7,2)                  ,
#     ws_net_paid_inc_tax       decimal(7,2)                  ,
#     ws_net_paid_inc_ship      decimal(7,2)                  ,
#     ws_net_paid_inc_ship_tax  decimal(7,2)                  ,
#     ws_net_profit             decimal(7,2)                  ,
#     primary key (ws_item_sk, ws_order_number)
# );
#
# result Table WEB_SALES successfully created.
# running query:
# create table catalog_sales
# (
#     cs_sold_date_sk           integer                       ,
#     cs_sold_time_sk           integer                       ,
#     cs_ship_date_sk           integer                       ,
#     cs_bill_customer_sk       integer                       ,
#     cs_bill_cdemo_sk          integer                       ,
#     cs_bill_hdemo_sk          integer                       ,
#     cs_bill_addr_sk           integer                       ,
#     cs_ship_customer_sk       integer                       ,
#     cs_ship_cdemo_sk          integer                       ,
#     cs_ship_hdemo_sk          integer                       ,
#     cs_ship_addr_sk           integer                       ,
#     cs_call_center_sk         integer                       ,
#     cs_catalog_page_sk        integer                       ,
#     cs_ship_mode_sk           integer                       ,
#     cs_warehouse_sk           integer                       ,
#     cs_item_sk                integer               not null,
#     cs_promo_sk               integer                       ,
#     cs_order_number           integer               not null,
#     cs_quantity               integer                       ,
#     cs_wholesale_cost         decimal(7,2)                  ,
#     cs_list_price             decimal(7,2)                  ,
#     cs_sales_price            decimal(7,2)                  ,
#     cs_ext_discount_amt       decimal(7,2)                  ,
#     cs_ext_sales_price        decimal(7,2)                  ,
#     cs_ext_wholesale_cost     decimal(7,2)                  ,
#     cs_ext_list_price         decimal(7,2)                  ,
#     cs_ext_tax                decimal(7,2)                  ,
#     cs_coupon_amt             decimal(7,2)                  ,
#     cs_ext_ship_cost          decimal(7,2)                  ,
#     cs_net_paid               decimal(7,2)                  ,
#     cs_net_paid_inc_tax       decimal(7,2)                  ,
#     cs_net_paid_inc_ship      decimal(7,2)                  ,
#     cs_net_paid_inc_ship_tax  decimal(7,2)                  ,
#     cs_net_profit             decimal(7,2)                  ,
#     primary key (cs_item_sk, cs_order_number)
# );
#
# result Table CATALOG_SALES successfully created.
# running query:
# create table store_sales
# (
#     ss_sold_date_sk           integer                       ,
#     ss_sold_time_sk           integer                       ,
#     ss_item_sk                integer               not null,
#     ss_customer_sk            integer                       ,
#     ss_cdemo_sk               integer                       ,
#     ss_hdemo_sk               integer                       ,
#     ss_addr_sk                integer                       ,
#     ss_store_sk               integer                       ,
#     ss_promo_sk               integer                       ,
#     ss_ticket_number          integer               not null,
#     ss_quantity               integer                       ,
#     ss_wholesale_cost         decimal(7,2)                  ,
#     ss_list_price             decimal(7,2)                  ,
#     ss_sales_price            decimal(7,2)                  ,
#     ss_ext_discount_amt       decimal(7,2)                  ,
#     ss_ext_sales_price        decimal(7,2)                  ,
#     ss_ext_wholesale_cost     decimal(7,2)                  ,
#     ss_ext_list_price         decimal(7,2)                  ,
#     ss_ext_tax                decimal(7,2)                  ,
#     ss_coupon_amt             decimal(7,2)                  ,
#     ss_net_paid               decimal(7,2)                  ,
#     ss_net_paid_inc_tax       decimal(7,2)                  ,
#     ss_net_profit             decimal(7,2)                  ,
#     primary key (ss_item_sk, ss_ticket_number)
# );
#
# result Table STORE_SALES successfully created.
#
#
# --finished pushing schema

# %% [markdown]
# ### Import Data from STAGE to target table

# %%
for table, files in db_files.items():
    print(f'Starting to import table: {table}')
    for file in sorted(files):
        print(f'\timporting file: {file}')
        sf_helper.import_data(table, file, integration_id)
        print(f'\tfinished @ {datetime.datetime.now().time()}')
# Out:
# Starting to import table: call_center
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_call_center_1_96.dat
# running query: copy into call_center from 'gcs://tpc-benchmark-5947/ds_1000GB_call_center_1_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_call_center_1_96.dat
# 	finished @ 19:11:42.797362
# Starting to import table: catalog_page
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_page_1_96.dat
# running query: copy into catalog_page from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_page_1_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_page_1_96.dat
# 	finished @ 19:11:52.363649
# Starting to import table: catalog_returns
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_10_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_10_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_10_96.dat
# 	finished @ 19:12:10.284006
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_11_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_11_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_11_96.dat
# 	finished @ 19:12:45.051933
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_12_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_12_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_12_96.dat
# 	finished @ 19:13:18.859157
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_13_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_13_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_13_96.dat
# 	finished @ 19:13:52.464058
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_14_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_14_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_14_96.dat
# 	finished @ 19:14:11.223616
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_15_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_15_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_15_96.dat
# 	finished @ 19:14:45.422486
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_16_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_16_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_16_96.dat
# 	finished @ 19:15:19.411344
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_17_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_17_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_17_96.dat
# 	finished @ 19:15:37.443736
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_18_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_18_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_18_96.dat
# 	finished @ 19:16:13.427400
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_19_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_19_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_19_96.dat
# 	finished @ 19:16:31.731624
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_1_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_1_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_1_96.dat
# 	finished @ 19:16:49.839267
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_20_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_20_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_20_96.dat
# 	finished @ 19:17:24.963686
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_21_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_21_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_21_96.dat
# 	finished @ 19:17:43.188037
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_22_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_22_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_22_96.dat
# 	finished @ 19:18:04.795649
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_23_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_23_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_23_96.dat
# 	finished @ 19:18:23.772335
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_24_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_24_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_24_96.dat
# 	finished @ 19:18:57.839965
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_25_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_25_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_25_96.dat
# 	finished @ 19:19:16.171846
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_26_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_26_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_26_96.dat
# 	finished @ 19:19:34.043413
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_27_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_27_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_27_96.dat
# 	finished @ 19:19:57.543967
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_28_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_28_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_28_96.dat
# 	finished @ 19:20:15.663867
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_29_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_29_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_29_96.dat
# 	finished @ 19:20:50.175639
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_2_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_2_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_2_96.dat
# 	finished @ 19:21:07.923731
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_30_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_30_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_30_96.dat
# 	finished @ 19:21:25.639787
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_31_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_31_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_31_96.dat
# 	finished @ 19:21:44.755206
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_32_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_32_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_32_96.dat
# 	finished @ 19:22:03.563697
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_33_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_33_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_33_96.dat
# 	finished @ 19:22:30.323500
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_34_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_34_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_34_96.dat
# 	finished @ 19:22:48.347386
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_35_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_35_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_35_96.dat
# 	finished @ 19:23:06.275348
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_36_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_36_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_36_96.dat
# 	finished @ 19:23:24.495485
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_37_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_37_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_37_96.dat
# 	finished @ 19:23:43.235495
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_38_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_38_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_38_96.dat
# 	finished @ 19:24:17.695872
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_39_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_39_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_39_96.dat
# 	finished @ 19:24:35.627310
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_3_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_3_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_3_96.dat
# 	finished @ 19:24:55.219279
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_40_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_40_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_40_96.dat
# 	finished @ 19:25:12.848382
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_41_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_41_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_41_96.dat
# 	finished @ 19:25:31.167613
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_42_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_42_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_42_96.dat
# 	finished @ 19:25:50.311379
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_43_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_43_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_43_96.dat
# 	finished @ 19:26:08.644031
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_44_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_44_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_44_96.dat
# 	finished @ 19:26:26.563968
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_45_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_45_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_45_96.dat
# 	finished @ 19:26:44.687949
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_46_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_46_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_46_96.dat
# 	finished @ 19:27:02.760279
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_47_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_47_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_47_96.dat
# 	finished @ 19:27:20.324250
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_48_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_48_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_48_96.dat
# 	finished @ 19:27:38.655467
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_49_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_49_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_49_96.dat
# 	finished @ 19:27:56.679682
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_4_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_4_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_4_96.dat
# 	finished @ 19:28:15.315664
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_50_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_50_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_50_96.dat
# 	finished @ 19:28:32.971242
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_51_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_51_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_51_96.dat
# 	finished @ 19:28:50.951406
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_52_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_52_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_52_96.dat
# 	finished @ 19:29:09.075785
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_53_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_53_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_53_96.dat
# 	finished @ 19:29:26.995398
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_54_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_54_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_54_96.dat
# 	finished @ 19:29:45.836123
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_55_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_55_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_55_96.dat
# 	finished @ 19:30:03.860011
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_56_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_56_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_56_96.dat
# 	finished @ 19:30:22.083971
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_57_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_57_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_57_96.dat
# 	finished @ 19:30:39.639983
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_58_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_58_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_58_96.dat
# 	finished @ 19:30:57.575814
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_59_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_59_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_59_96.dat
# 	finished @ 19:31:15.219620
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_5_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_5_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_5_96.dat
# 	finished @ 19:31:32.907980
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_60_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_60_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_60_96.dat
# 	finished @ 19:31:52.735536
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_61_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_61_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_61_96.dat
# 	finished @ 19:32:11.428116
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_62_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_62_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_62_96.dat
# 	finished @ 19:32:29.999417
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_63_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_63_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_63_96.dat
# 	finished @ 19:32:50.351857
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_64_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_64_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_64_96.dat
# 	finished @ 19:33:08.914750
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_65_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_65_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_65_96.dat
# 	finished @ 19:33:26.505919
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_66_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_66_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_66_96.dat
# 	finished @ 19:33:44.472161
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_67_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_67_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_67_96.dat
# 	finished @ 19:34:02.084164
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_68_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_68_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_68_96.dat
# 	finished @ 19:34:19.991731
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_69_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_69_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_69_96.dat
# 	finished @ 19:34:38.547741
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_6_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_6_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_6_96.dat
# 	finished @ 19:34:56.129365
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_70_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_70_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_70_96.dat
# 	finished @ 19:35:14.872355
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_71_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_71_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_71_96.dat
# 	finished @ 19:35:32.327682
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_72_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_72_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_72_96.dat
# 	finished @ 19:35:50.747987
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_73_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_73_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_73_96.dat
# 	finished @ 19:36:12.251644
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_74_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_74_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_74_96.dat
# 	finished @ 19:36:29.491863
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_75_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_75_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_75_96.dat
# 	finished @ 19:36:46.579616
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_76_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_76_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_76_96.dat
# 	finished @ 19:37:04.735714
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_77_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_77_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_77_96.dat
# 	finished @ 19:37:22.683752
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_78_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_78_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_78_96.dat
# 	finished @ 19:37:40.778537
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_79_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_79_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_79_96.dat
# 	finished @ 19:37:58.140197
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_7_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_7_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_7_96.dat
# 	finished @ 19:38:19.015579
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_80_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_80_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_80_96.dat
# 	finished @ 19:38:36.559346
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_81_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_81_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_81_96.dat
# 	finished @ 19:38:56.223498
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_82_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_82_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_82_96.dat
# 	finished @ 19:39:14.159771
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_83_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_83_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_83_96.dat
# 	finished @ 19:39:31.980165
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_84_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_84_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_84_96.dat
# 	finished @ 19:39:50.000066
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_85_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_85_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_85_96.dat
# 	finished @ 19:40:08.740973
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_86_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_86_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_86_96.dat
# 	finished @ 19:40:27.071921
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_87_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_87_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_87_96.dat
# 	finished @ 19:40:44.887902
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_88_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_88_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_88_96.dat
# 	finished @ 19:41:02.124513
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_89_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_89_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_89_96.dat
# 	finished @ 19:41:20.831517
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_8_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_8_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_8_96.dat
# 	finished @ 19:41:39.140229
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_90_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_90_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_90_96.dat
# 	finished @ 19:41:56.572346
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_91_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_91_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_91_96.dat
# 	finished @ 19:42:15.307616
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_92_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_92_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_92_96.dat
# 	finished @ 19:42:33.159503
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_93_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_93_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_93_96.dat
# 	finished @ 19:42:50.767576
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_94_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_94_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_94_96.dat
# 	finished @ 19:43:09.375943
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_95_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_95_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_95_96.dat
# 	finished @ 19:43:28.320400
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_96_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_96_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_96_96.dat
# 	finished @ 19:43:46.240028
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_9_96.dat
# running query: copy into catalog_returns from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_9_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_returns_9_96.dat
# 	finished @ 19:44:03.955520
# Starting to import table: catalog_sales
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_10_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_10_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_10_96.dat
# 	finished @ 19:46:03.972761
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_11_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_11_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_11_96.dat
# 	finished @ 19:48:12.176112
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_12_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_12_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_12_96.dat
# 	finished @ 19:50:15.263236
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_13_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_13_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_13_96.dat
# 	finished @ 19:52:19.643713
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_14_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_14_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_14_96.dat
# 	finished @ 19:54:17.440118
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_15_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_15_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_15_96.dat
# 	finished @ 19:56:20.731659
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_16_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_16_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_16_96.dat
# 	finished @ 19:58:19.415316
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_17_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_17_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_17_96.dat
# 	finished @ 20:00:21.067260
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_18_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_18_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_18_96.dat
# 	finished @ 20:02:24.769046
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_19_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_19_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_19_96.dat
# 	finished @ 20:04:28.199943
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_1_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_1_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_1_96.dat
# 	finished @ 20:06:28.451863
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_20_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_20_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_20_96.dat
# 	finished @ 20:08:32.348254
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_21_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_21_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_21_96.dat
# 	finished @ 20:10:35.579908
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_22_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_22_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_22_96.dat
# 	finished @ 20:12:38.524094
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_23_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_23_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_23_96.dat
# 	finished @ 20:14:38.067603
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_24_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_24_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_24_96.dat
# 	finished @ 20:16:57.540402
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_25_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_25_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_25_96.dat
# 	finished @ 20:18:58.983529
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_26_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_26_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_26_96.dat
# 	finished @ 20:21:03.915678
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_27_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_27_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_27_96.dat
# 	finished @ 20:23:15.456257
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_28_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_28_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_28_96.dat
# 	finished @ 20:25:15.719637
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_29_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_29_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_29_96.dat
# 	finished @ 20:27:17.987456
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_2_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_2_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_2_96.dat
# 	finished @ 20:29:15.237711
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_30_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_30_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_30_96.dat
# 	finished @ 20:31:27.535698
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_31_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_31_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_31_96.dat
# 	finished @ 20:33:33.899497
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_32_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_32_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_32_96.dat
# 	finished @ 20:35:34.742119
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_33_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_33_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_33_96.dat
# 	finished @ 20:37:54.820093
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_34_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_34_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_34_96.dat
# 	finished @ 20:39:53.191548
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_35_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_35_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_35_96.dat
# 	finished @ 20:41:55.768250
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_36_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_36_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_36_96.dat
# 	finished @ 20:44:08.481222
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_37_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_37_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_37_96.dat
# 	finished @ 20:46:11.563673
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_38_96.dat
# running query: copy into catalog_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_38_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_38_96.dat
# 	finished @ 20:48:14.344000
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_catalog_sales_39_96.dat
# ...
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_57_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_57_96.dat
# 	finished @ 06:30:50.600162
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_58_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_58_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_58_96.dat
# 	finished @ 06:31:50.298992
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_59_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_59_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_59_96.dat
# 	finished @ 06:32:54.915736
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_5_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_5_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_5_96.dat
# 	finished @ 06:33:58.047562
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_60_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_60_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_60_96.dat
# 	finished @ 06:35:02.810993
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_61_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_61_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_61_96.dat
# 	finished @ 06:36:09.579077
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_62_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_62_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_62_96.dat
# 	finished @ 06:37:20.033968
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_63_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_63_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_63_96.dat
# 	finished @ 06:38:26.719022
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_64_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_64_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_64_96.dat
# 	finished @ 06:39:48.534715
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_65_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_65_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_65_96.dat
# 	finished @ 06:40:52.003931
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_66_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_66_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_66_96.dat
# 	finished @ 06:42:04.911235
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_67_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_67_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_67_96.dat
# 	finished @ 06:43:07.475744
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_68_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_68_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_68_96.dat
# 	finished @ 06:44:11.179148
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_69_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_69_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_69_96.dat
# 	finished @ 06:45:16.195389
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_6_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_6_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_6_96.dat
# 	finished @ 06:46:20.299059
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_70_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_70_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_70_96.dat
# 	finished @ 06:47:25.114903
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_71_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_71_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_71_96.dat
# 	finished @ 06:48:33.467282
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_72_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_72_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_72_96.dat
# 	finished @ 06:49:36.803088
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_73_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_73_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_73_96.dat
# 	finished @ 06:50:39.475995
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_74_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_74_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_74_96.dat
# 	finished @ 06:51:41.430936
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_75_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_75_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_75_96.dat
# 	finished @ 06:52:46.043068
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_76_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_76_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_76_96.dat
# 	finished @ 06:54:03.867130
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_77_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_77_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_77_96.dat
# 	finished @ 06:55:09.240378
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_78_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_78_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_78_96.dat
# 	finished @ 06:56:15.043341
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_79_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_79_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_79_96.dat
# 	finished @ 06:57:18.879286
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_7_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_7_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_7_96.dat
# 	finished @ 06:58:32.055639
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_80_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_80_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_80_96.dat
# 	finished @ 06:59:37.390846
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_81_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_81_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_81_96.dat
# 	finished @ 07:00:42.718961
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_82_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_82_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_82_96.dat
# 	finished @ 07:01:56.038892
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_83_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_83_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_83_96.dat
# 	finished @ 07:03:00.039126
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_84_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_84_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_84_96.dat
# 	finished @ 07:04:04.354769
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_85_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_85_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_85_96.dat
# 	finished @ 07:06:09.751117
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_86_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_86_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_86_96.dat
# 	finished @ 07:07:12.359460
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_87_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_87_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_87_96.dat
# 	finished @ 07:08:25.957997
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_88_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_88_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_88_96.dat
# 	finished @ 07:09:44.115006
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_89_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_89_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_89_96.dat
# 	finished @ 07:10:46.375028
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_8_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_8_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_8_96.dat
# 	finished @ 07:11:52.834955
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_90_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_90_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_90_96.dat
# 	finished @ 07:12:57.963913
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_91_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_91_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_91_96.dat
# 	finished @ 07:13:59.167105
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_92_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_92_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_92_96.dat
# 	finished @ 07:15:22.555050
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_93_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_93_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_93_96.dat
# 	finished @ 07:16:35.286828
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_94_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_94_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_94_96.dat
# 	finished @ 07:17:40.243762
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_95_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_95_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_95_96.dat
# 	finished @ 07:18:46.084546
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_96_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_96_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_96_96.dat
# 	finished @ 07:19:48.078865
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_sales_9_96.dat
# running query: copy into web_sales from 'gcs://tpc-benchmark-5947/ds_1000GB_web_sales_9_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_sales_9_96.dat
# 	finished @ 07:20:53.512485
# Starting to import table: web_site
# 	importing file: gcs://tpc-benchmark-5947/ds_1000GB_web_site_1_96.dat
# running query: copy into web_site from 'gcs://tpc-benchmark-5947/ds_1000GB_web_site_1_96.dat' storage_integration=gcs_ds_1000GB_integration file_format=(format_name=csv_file_format);
# result gcs://tpc-benchmark-5947/ds_1000GB_web_site_1_96.dat
# 	finished @ 07:21:00.475691

# %% [markdown]
# ### Suspend WAREHOUSE

# %%
sf_helper.warehouse_suspend()
# Out:
# warehouse suspend: Statement executed successfully.
