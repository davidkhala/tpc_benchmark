# %% [markdown]
# ## TPC-H & TPC-DS BigQuery Data Import
# Import data from GCS to a previously created BigQuery dataset.
#
# This Notebook assumes that you've already generated data at one or more scale factors and uploaded them to the project Google Cloud Storage bucket listed in `config.gcs_data_bucket`
#
# Three values are required to initiate an upload to BigQuery:
# 1. `test` - the test name, either `h` or `ds`
# 2. `scale` - the scale factor in GB, usually this will be `1, 100, 1000, 10000`
# 3. `name` - name of this instance of the `test` and `scale` combination, i.e. `time-partitioned`

# %%
import config, bq

# %%
import pandas as pd

# %%
pd.set_option("display.max_rows", 1000)
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# #### Upload Variables

# %%
test = "ds"
scale = 100
cid = "01"
schema = "bq_ds_01.sql"

# %%
dataset_name = "{}_{}GB_{}".format(test, scale, cid)
dataset_name
# Out:
# 'ds_100GB_01'

# %%
ddl_filepath = config.fp_schema + config.sep + schema

# %%
bq.create_dataset(dataset_name=dataset_name)
# Out:
# Dataset(DatasetReference('tpc-benchmarking-9432', 'ds_100GB_01'))

# %%
bq.create_schema(schema_file=ddl_filepath, dataset=dataset_name)

# %%
bq_upload = bq.BQUpload(test=test, scale=scale, dataset=dataset_name)

# %% [markdown]
# #### Initiate Upload
# set `verbose=True` for status printouts.

# %%
fp = bq_upload.upload(verbose=True)
# Out:
# Tables to upload:
# call_center
# catalog_page
# catalog_returns
# catalog_sales
# customer
# customer_address
# customer_demographics
# date_dim
# household_demographics
# income_band
# inventory
# item
# promotion
# reason
# ship_mode
# store
# store_returns
# store_sales
# time_dim
# warehouse
# web_page
# web_returns
# web_sales
# web_site
# Loading Table: call_center
# t0: 2020-07-09 22:23:32.026483
# ...
# t1: 2020-07-09 22:23:34.883012
# Load Job Done: True
# ID: 3a642435-44d2-472a-af32-a6d5f195def7
# dt: 0 days 00:00:02.856529
# GB/s: 0.00
# ------------------------------
# Loading Table: catalog_page
# t0: 2020-07-09 22:23:34.884551
# ...
# t1: 2020-07-09 22:23:45.401323
# Load Job Done: True
# ID: 23e43480-4cdf-49ac-9316-ded51eb52793
# dt: 0 days 00:00:10.516772
# GB/s: 0.00
# ------------------------------
# Loading Table: catalog_returns
# t0: 2020-07-09 22:23:45.402857
# ...
# t1: 2020-07-09 22:25:05.539592
# Load Job Done: True
# ID: 1d2885fc-35bf-4287-aee0-a9c2fb73d087
# dt: 0 days 00:01:20.136735
# GB/s: 0.03
# ------------------------------
# Loading Table: catalog_sales
# t0: 2020-07-09 22:25:05.541085
# ...
# t1: 2020-07-09 22:26:41.941668
# Load Job Done: True
# ID: 26dcd9e3-4639-4519-bf69-0c0a90135d66
# dt: 0 days 00:01:36.400583
# GB/s: 0.32
# ------------------------------
# Loading Table: customer
# t0: 2020-07-09 22:26:41.943236
# ...
# t1: 2020-07-09 22:28:09.157572
# Load Job Done: True
# ID: fcbb330e-ea05-4f9a-b8b0-76b2390f5b68
# dt: 0 days 00:01:27.214336
# GB/s: 0.00
# ------------------------------
# Loading Table: customer_address
# t0: 2020-07-09 22:28:09.159174
# ...
# t1: 2020-07-09 22:28:43.751888
# Load Job Done: True
# ID: 53e2e2a3-b2b7-4cd2-84b5-3440422e9022
# dt: 0 days 00:00:34.592714
# GB/s: 0.00
# ------------------------------
# Loading Table: customer_demographics
# t0: 2020-07-09 22:28:43.753388
# ...
# t1: 2020-07-09 22:29:07.555146
# Load Job Done: True
# ID: a7e9d9c6-f662-4726-8500-6e783aad2a92
# dt: 0 days 00:00:23.801758
# GB/s: 0.00
# ------------------------------
# Loading Table: date_dim
# t0: 2020-07-09 22:29:07.556718
# ...
# t1: 2020-07-09 22:29:14.312507
# Load Job Done: True
# ID: 859a7370-20b2-45f2-b4b7-86860149e068
# dt: 0 days 00:00:06.755789
# GB/s: 0.00
# ------------------------------
# Loading Table: household_demographics
# t0: 2020-07-09 22:29:14.314119
# ...
# t1: 2020-07-09 22:29:19.379723
# Load Job Done: True
# ID: 4d0bf15c-60a8-4dc6-ab51-1f9c9fa96511
# dt: 0 days 00:00:05.065604
# GB/s: 0.00
# ------------------------------
# Loading Table: income_band
# t0: 2020-07-09 22:29:19.381387
# ...
# t1: 2020-07-09 22:29:22.709689
# Load Job Done: True
# ID: 104b0396-f9ad-4641-914d-6452607d050a
# dt: 0 days 00:00:03.328302
# GB/s: 0.00
# ------------------------------
# Loading Table: inventory
# t0: 2020-07-09 22:29:22.711404
# ...
# t1: 2020-07-09 22:30:27.358813
# Load Job Done: True
# ID: e22c3801-1ff2-4c67-80f5-7de6a6e9d487
# dt: 0 days 00:01:04.647409
# GB/s: 0.13
# ------------------------------
# Loading Table: item
# t0: 2020-07-09 22:30:27.360145
# ...
# t1: 2020-07-09 22:30:44.190650
# Load Job Done: True
# ID: 2d8d4a04-0aea-435b-9f8f-c7e58c8f37d9
# dt: 0 days 00:00:16.830505
# GB/s: 0.00
# ------------------------------
# Loading Table: promotion
# t0: 2020-07-09 22:30:44.191784
# ...
# t1: 2020-07-09 22:30:46.929282
# Load Job Done: True
# ID: f2ac825a-c7df-4d06-a1e7-55768f79db6a
# dt: 0 days 00:00:02.737498
# GB/s: 0.00
# ------------------------------
# Loading Table: reason
# t0: 2020-07-09 22:30:46.930667
# ...
# t1: 2020-07-09 22:30:49.752244
# Load Job Done: True
# ID: 4db5ea59-7340-4a2d-8342-85b2f3d4a176
# dt: 0 days 00:00:02.821577
# GB/s: 0.00
# ------------------------------
# Loading Table: ship_mode
# t0: 2020-07-09 22:30:49.753578
# ...
# t1: 2020-07-09 22:30:51.991439
# Load Job Done: True
# ID: 54c6386c-eb87-4d86-a6b5-74274bb3a4c7
# dt: 0 days 00:00:02.237861
# GB/s: 0.00
# ------------------------------
# Loading Table: store
# t0: 2020-07-09 22:30:51.992667
# ...
# t1: 2020-07-09 22:30:57.190461
# Load Job Done: True
# ID: 712c7bda-faab-4e23-9024-786c4680510f
# dt: 0 days 00:00:05.197794
# GB/s: 0.00
# ------------------------------
# Loading Table: store_returns
# t0: 2020-07-09 22:30:57.191892
# ...
# t1: 2020-07-09 22:32:21.680244
# Load Job Done: True
# ID: a12c00cc-0571-4a39-ab22-00bfd8458972
# dt: 0 days 00:01:24.488352
# GB/s: 0.04
# ------------------------------
# Loading Table: store_sales
# t0: 2020-07-09 22:32:21.681820
# ...
# t1: 2020-07-09 22:34:32.778825
# Load Job Done: True
# ID: 4c8d89c8-e1a7-429f-ab5b-85a407e48a63
# dt: 0 days 00:02:11.097005
# GB/s: 0.31
# ------------------------------
# Loading Table: time_dim
# t0: 2020-07-09 22:34:32.780167
# ...
# t1: 2020-07-09 22:34:41.994494
# Load Job Done: True
# ID: 6b89419a-c781-4bcc-861a-0e9a1e1ee45b
# dt: 0 days 00:00:09.214327
# GB/s: 0.00
# ------------------------------
# Loading Table: warehouse
# t0: 2020-07-09 22:34:41.996121
# ...
# t1: 2020-07-09 22:34:46.498434
# Load Job Done: True
# ID: 4fded74a-4fb9-4c70-9807-853f854f80b3
# dt: 0 days 00:00:04.502313
# GB/s: 0.00
# ------------------------------
# Loading Table: web_page
# t0: 2020-07-09 22:34:46.499864
# ...
# t1: 2020-07-09 22:34:50.484207
# Load Job Done: True
# ID: f9bbdaa4-c04e-4bb4-88e7-489af765074b
# dt: 0 days 00:00:03.984343
# GB/s: 0.00
# ------------------------------
# Loading Table: web_returns
# t0: 2020-07-09 22:34:50.485467
# ...
# t1: 2020-07-09 22:36:38.733206
# Load Job Done: True
# ID: a3ca9d24-3448-4bc6-8f85-28b5a1fc0e60
# dt: 0 days 00:01:48.247739
# GB/s: 0.01
# ------------------------------
# Loading Table: web_sales
# t0: 2020-07-09 22:36:38.735032
# ...
# t1: 2020-07-09 22:38:13.554287
# Load Job Done: True
# ID: a9b849c0-3c63-44e1-bb6d-ff925996dbca
# dt: 0 days 00:01:34.819255
# GB/s: 0.16
# ------------------------------
# Loading Table: web_site
# t0: 2020-07-09 22:38:13.555693
# ...
# t1: 2020-07-09 22:38:18.351542
# Load Job Done: True
# ID: c907561b-994f-484f-9a7f-c3b0d607c754
# dt: 0 days 00:00:04.795849
# GB/s: 0.00
# ------------------------------
# ========================================
# Total load time: 0 days 00:14:46.341861
# Total size: 102.460 GB
# Speed: 0.116 GB/s

# %% [markdown]
# #### Summary of Upload

# %%
fp
# Out:
# '/home/colin/code/bq_snowflake_benchmark/ds/bq_upload-ds_100GB-ds_100GB_01-2020-07-09 22:23:32.010143.csv'

# %%
dfa = bq.parse_log(fp)
dfa
# Out:
#     test  scale      dataset                   table  status  \
# 0   test  scale      dataset                   table  status
# 1     ds    100  ds_100GB_01             call_center   start
# 2     ds    100  ds_100GB_01             call_center     end
# 3     ds    100  ds_100GB_01            catalog_page   start
# 4     ds    100  ds_100GB_01            catalog_page     end
# 5     ds    100  ds_100GB_01         catalog_returns   start
# 6     ds    100  ds_100GB_01         catalog_returns     end
# 7     ds    100  ds_100GB_01           catalog_sales   start
# 8     ds    100  ds_100GB_01           catalog_sales     end
# 9     ds    100  ds_100GB_01                customer   start
# 10    ds    100  ds_100GB_01                customer     end
# 11    ds    100  ds_100GB_01        customer_address   start
# 12    ds    100  ds_100GB_01        customer_address     end
# 13    ds    100  ds_100GB_01   customer_demographics   start
# 14    ds    100  ds_100GB_01   customer_demographics     end
# 15    ds    100  ds_100GB_01                date_dim   start
# 16    ds    100  ds_100GB_01                date_dim     end
# 17    ds    100  ds_100GB_01  household_demographics   start
# 18    ds    100  ds_100GB_01  household_demographics     end
# 19    ds    100  ds_100GB_01             income_band   start
# 20    ds    100  ds_100GB_01             income_band     end
# 21    ds    100  ds_100GB_01               inventory   start
# 22    ds    100  ds_100GB_01               inventory     end
# 23    ds    100  ds_100GB_01                    item   start
# 24    ds    100  ds_100GB_01                    item     end
# 25    ds    100  ds_100GB_01               promotion   start
# 26    ds    100  ds_100GB_01               promotion     end
# 27    ds    100  ds_100GB_01                  reason   start
# 28    ds    100  ds_100GB_01                  reason     end
# 29    ds    100  ds_100GB_01               ship_mode   start
# 30    ds    100  ds_100GB_01               ship_mode     end
# 31    ds    100  ds_100GB_01                   store   start
# 32    ds    100  ds_100GB_01                   store     end
# 33    ds    100  ds_100GB_01           store_returns   start
# 34    ds    100  ds_100GB_01           store_returns     end
# 35    ds    100  ds_100GB_01             store_sales   start
# 36    ds    100  ds_100GB_01             store_sales     end
# 37    ds    100  ds_100GB_01                time_dim   start
# 38    ds    100  ds_100GB_01                time_dim     end
# 39    ds    100  ds_100GB_01               warehouse   start
# 40    ds    100  ds_100GB_01               warehouse     end
# 41    ds    100  ds_100GB_01                web_page   start
# 42    ds    100  ds_100GB_01                web_page     end
# 43    ds    100  ds_100GB_01             web_returns   start
# 44    ds    100  ds_100GB_01             web_returns     end
# 45    ds    100  ds_100GB_01               web_sales   start
# 46    ds    100  ds_100GB_01               web_sales     end
# 47    ds    100  ds_100GB_01                web_site   start
# 48    ds    100  ds_100GB_01                web_site     end
#
#                             t0                          t1   size_bytes  \
# 0                           t0                          t1   size_bytes
# 1   2020-07-09 22:23:32.026483                         NaN         9389
# 2   2020-07-09 22:23:32.026483  2020-07-09 22:23:34.883012         9389
# 3   2020-07-09 22:23:34.884551                         NaN      2833824
# 4   2020-07-09 22:23:34.884551  2020-07-09 22:23:45.401323      2833824
# 5   2020-07-09 22:23:45.402857                         NaN   2264498800
# 6   2020-07-09 22:23:45.402857  2020-07-09 22:25:05.539592   2264498800
# 7   2020-07-09 22:25:05.541085                         NaN  30874934982
# 8   2020-07-09 22:25:05.541085  2020-07-09 22:26:41.941668  30874934982
# 9   2020-07-09 22:26:41.943236                         NaN    267479876
# 10  2020-07-09 22:26:41.943236  2020-07-09 22:28:09.157572    267479876
# 11  2020-07-09 22:28:09.159174                         NaN    110152133
# 12  2020-07-09 22:28:09.159174  2020-07-09 22:28:43.751888    110152133
# 13  2020-07-09 22:28:43.753388                         NaN     78739296
# 14  2020-07-09 22:28:43.753388  2020-07-09 22:29:07.555146     78739296
# 15  2020-07-09 22:29:07.556718                         NaN     10244389
# 16  2020-07-09 22:29:07.556718  2020-07-09 22:29:14.312507     10244389
# 17  2020-07-09 22:29:14.314119                         NaN       144453
# 18  2020-07-09 22:29:14.314119  2020-07-09 22:29:19.379723       144453
# 19  2020-07-09 22:29:19.381387                         NaN          308
# 20  2020-07-09 22:29:19.381387  2020-07-09 22:29:22.709689          308
# 21  2020-07-09 22:29:22.711404                         NaN   8226927006
# 22  2020-07-09 22:29:22.711404  2020-07-09 22:30:27.358813   8226927006
# 23  2020-07-09 22:30:27.360145                         NaN     58194149
# 24  2020-07-09 22:30:27.360145  2020-07-09 22:30:44.190650     58194149
# 25  2020-07-09 22:30:44.191784                         NaN       123909
# 26  2020-07-09 22:30:44.191784  2020-07-09 22:30:46.929282       123909
# 27  2020-07-09 22:30:46.930667                         NaN         1904
# 28  2020-07-09 22:30:46.930667  2020-07-09 22:30:49.752244         1904
# 29  2020-07-09 22:30:49.753578                         NaN         1062
# 30  2020-07-09 22:30:49.753578  2020-07-09 22:30:51.991439         1062
# 31  2020-07-09 22:30:51.992667                         NaN       106691
# 32  2020-07-09 22:30:51.992667  2020-07-09 22:30:57.190461       106691
# 33  2020-07-09 22:30:57.191892                         NaN   3455086997
# 34  2020-07-09 22:30:57.191892  2020-07-09 22:32:21.680244   3455086997
# 35  2020-07-09 22:32:21.681820                         NaN  40670126159
# 36  2020-07-09 22:32:21.681820  2020-07-09 22:34:32.778825  40670126159
# 37  2020-07-09 22:34:32.780167                         NaN      5021380
# 38  2020-07-09 22:34:32.780167  2020-07-09 22:34:41.994494      5021380
# 39  2020-07-09 22:34:41.996121                         NaN         1790
# 40  2020-07-09 22:34:41.996121  2020-07-09 22:34:46.498434         1790
# 41  2020-07-09 22:34:46.499864                         NaN       197342
# 42  2020-07-09 22:34:46.499864  2020-07-09 22:34:50.484207       197342
# 43  2020-07-09 22:34:50.485467                         NaN   1046374972
# 44  2020-07-09 22:34:50.485467  2020-07-09 22:36:38.733206   1046374972
# 45  2020-07-09 22:36:38.735032                         NaN  15388867955
# 46  2020-07-09 22:36:38.735032  2020-07-09 22:38:13.554287  15388867955
# 47  2020-07-09 22:38:13.555693                         NaN         6747
# 48  2020-07-09 22:38:13.555693  2020-07-09 22:38:18.351542         6747
#
#                                   job_id
# 0                                 job_id
# 1                                    NaN
# 2   3a642435-44d2-472a-af32-a6d5f195def7
# 3                                    NaN
# 4   23e43480-4cdf-49ac-9316-ded51eb52793
# 5                                    NaN
# 6   1d2885fc-35bf-4287-aee0-a9c2fb73d087
# 7                                    NaN
# 8   26dcd9e3-4639-4519-bf69-0c0a90135d66
# 9                                    NaN
# 10  fcbb330e-ea05-4f9a-b8b0-76b2390f5b68
# 11                                   NaN
# 12  53e2e2a3-b2b7-4cd2-84b5-3440422e9022
# 13                                   NaN
# 14  a7e9d9c6-f662-4726-8500-6e783aad2a92
# 15                                   NaN
# 16  859a7370-20b2-45f2-b4b7-86860149e068
# 17                                   NaN
# 18  4d0bf15c-60a8-4dc6-ab51-1f9c9fa96511
# 19                                   NaN
# 20  104b0396-f9ad-4641-914d-6452607d050a
# 21                                   NaN
# 22  e22c3801-1ff2-4c67-80f5-7de6a6e9d487
# 23                                   NaN
# 24  2d8d4a04-0aea-435b-9f8f-c7e58c8f37d9
# 25                                   NaN
# 26  f2ac825a-c7df-4d06-a1e7-55768f79db6a
# 27                                   NaN
# 28  4db5ea59-7340-4a2d-8342-85b2f3d4a176
# 29                                   NaN
# 30  54c6386c-eb87-4d86-a6b5-74274bb3a4c7
# 31                                   NaN
# 32  712c7bda-faab-4e23-9024-786c4680510f
# 33                                   NaN
# 34  a12c00cc-0571-4a39-ab22-00bfd8458972
# 35                                   NaN
# 36  4c8d89c8-e1a7-429f-ab5b-85a407e48a63
# 37                                   NaN
# 38  6b89419a-c781-4bcc-861a-0e9a1e1ee45b
# 39                                   NaN
# 40  4fded74a-4fb9-4c70-9807-853f854f80b3
# 41                                   NaN
# 42  f9bbdaa4-c04e-4bb4-88e7-489af765074b
# 43                                   NaN
# 44  a3ca9d24-3448-4bc6-8f85-28b5a1fc0e60
# 45                                   NaN
# 46  a9b849c0-3c63-44e1-bb6d-ff925996dbca
# 47                                   NaN
# 48  c907561b-994f-484f-9a7f-c3b0d607c754
