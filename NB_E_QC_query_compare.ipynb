# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import qc, config, tools, sfa

from importlib import reload

pd.options.display.max_rows = 9999
pd.options.display.max_columns = 9999
pd.set_option('precision', 7)

# %% [markdown]
# ### Single Query Result Comparison

# %%
query_n = 75

a = qc.QueryQC()
a.test = "ds"
a.scale = 1
a.cid = "01"
a.stream_n = 1
a.desc =  f"qc_query"
a.seq_id = "NA"

a.verbose = False
a.verbose_query = True
a.qual = False
a.save = False
a.verbose_iter = True

a.set_timestamp_dir()

a.run_single(query_n=query_n)
# Out:
# SNOWFLAKE QUERY TEXT
# ====================
# ALTER SESSION SET TIMEZONE = 'UTC'
#
# SNOWFLAKE QUERY TEXT
# ====================
# ALTER SESSION SET QUERY_TAG = 'ds_1gb_01-xx-qc_query'
#
# SNOWFLAKE QUERY TEXT
# ====================
# ALTER SESSION SET USE_CACHED_RESULT=false
#
# SNOWFLAKE QUERY TEXT
# ====================
# USE WAREHOUSE TEST9000
#
# SNOWFLAKE QUERY TEXT
# ====================
# USE DATABASE ds_1GB_01
#
# ========================================
# Snowflake Start Query: 75
# --------------------
# Stream Completion: 1 / 1
# Query Label: ds_1gb_01-q75-1-qc_query
# --------------------
#
# SNOWFLAKE QUERY TEXT
# ====================
# ALTER SESSION SET QUERY_TAG = 'ds_1gb_01-q75-1-qc_query'
#
# SNOWFLAKE QUERY TEXT
# ====================
#
# WITH all_sales AS (
#  SELECT d_year
#        ,i_brand_id
#        ,i_class_id
#        ,i_category_id
#        ,i_manufact_id
#        ,SUM(sales_cnt) AS sales_cnt
#        ,SUM(sales_amt) AS sales_amt
#  FROM (SELECT d_year
#              ,i_brand_id
#              ,i_class_id
#              ,i_category_id
#              ,i_manufact_id
#              ,cs_quantity - COALESCE(cr_return_quantity,0) AS sales_cnt
#              ,cs_ext_sales_price - COALESCE(cr_return_amount,0.0) AS sales_amt
#        FROM catalog_sales JOIN item ON i_item_sk=cs_item_sk
#                           JOIN date_dim ON d_date_sk=cs_sold_date_sk
#                           LEFT JOIN catalog_returns ON (cs_order_number=cr_order_number
#                                                     AND cs_item_sk=cr_item_sk)
#        WHERE i_category='Electronics'
#        UNION
#        SELECT d_year
#              ,i_brand_id
#              ,i_class_id
#              ,i_category_id
#              ,i_manufact_id
#              ,ss_quantity - COALESCE(sr_return_quantity,0) AS sales_cnt
#              ,ss_ext_sales_price - COALESCE(sr_return_amt,0.0) AS sales_amt
#        FROM store_sales JOIN item ON i_item_sk=ss_item_sk
#                         JOIN date_dim ON d_date_sk=ss_sold_date_sk
#                         LEFT JOIN store_returns ON (ss_ticket_number=sr_ticket_number
#                                                 AND ss_item_sk=sr_item_sk)
#        WHERE i_category='Electronics'
#        UNION
#        SELECT d_year
#              ,i_brand_id
#              ,i_class_id
#              ,i_category_id
#              ,i_manufact_id
#              ,ws_quantity - COALESCE(wr_return_quantity,0) AS sales_cnt
#              ,ws_ext_sales_price - COALESCE(wr_return_amt,0.0) AS sales_amt
#        FROM web_sales JOIN item ON i_item_sk=ws_item_sk
#                       JOIN date_dim ON d_date_sk=ws_sold_date_sk
#                       LEFT JOIN web_returns ON (ws_order_number=wr_order_number
#                                             AND ws_item_sk=wr_item_sk)
#        WHERE i_category='Electronics') sales_detail
#  GROUP BY d_year, i_brand_id, i_class_id, i_category_id, i_manufact_id)
#  SELECT  prev_yr.d_year AS prev_year
#                           ,curr_yr.d_year AS year
#                           ,curr_yr.i_brand_id
#                           ,curr_yr.i_class_id
#                           ,curr_yr.i_category_id
#                           ,curr_yr.i_manufact_id
#                           ,prev_yr.sales_cnt AS prev_yr_cnt
#                           ,curr_yr.sales_cnt AS curr_yr_cnt
#                           ,curr_yr.sales_cnt-prev_yr.sales_cnt AS sales_cnt_diff
#                           ,curr_yr.sales_amt-prev_yr.sales_amt AS sales_amt_diff
#  FROM all_sales curr_yr, all_sales prev_yr
#  WHERE curr_yr.i_brand_id=prev_yr.i_brand_id
#    AND curr_yr.i_class_id=prev_yr.i_class_id
#    AND curr_yr.i_category_id=prev_yr.i_category_id
#    AND curr_yr.i_manufact_id=prev_yr.i_manufact_id
#    AND curr_yr.d_year=2001
#    AND prev_yr.d_year=2001-1
#    AND CAST(curr_yr.sales_cnt AS DECIMAL(17,2))/CAST(prev_yr.sales_cnt AS DECIMAL(17,2))<0.9
#  ORDER BY
#   sales_cnt_diff nulls last,
#   sales_amt_diff nulls last
#  limit 100;
#
#
#
#
# Query ID: 0195774d-02eb-efb2-0009-c0830006f322
# Total Time Elapsed: 0 days 00:00:00.924000
# ----------------------------------------
#
#
# ========================================
# Snowflake Query Stream Done!
# Total Time Elapsed: 0 days 00:00:01.001604
#
# ========================================
# BigQuery Start Query: 75
# --------------------
# Stream Completion: 1 / 1
# Query Label: ds_1gb_01-q75-1-qc_query
# --------------------
#
# BIGQUERY QUERY TEXT
# ===================
#
# WITH all_sales AS (
#  SELECT d_year
#        ,i_brand_id
#        ,i_class_id
#        ,i_category_id
#        ,i_manufact_id
#        ,SUM(sales_cnt) AS sales_cnt
#        ,SUM(sales_amt) AS sales_amt
#  FROM (SELECT d_year
#              ,i_brand_id
#              ,i_class_id
#              ,i_category_id
#              ,i_manufact_id
#              ,cs_quantity - COALESCE(cr_return_quantity,0) AS sales_cnt
#              ,cs_ext_sales_price - COALESCE(cr_return_amount,0.0) AS sales_amt
#        FROM catalog_sales JOIN item ON i_item_sk=cs_item_sk
#                           JOIN date_dim ON d_date_sk=cs_sold_date_sk
#                           LEFT JOIN catalog_returns ON (cs_order_number=cr_order_number
#                                                     AND cs_item_sk=cr_item_sk)
#        WHERE i_category='Electronics'
#        UNION DISTINCT
#        SELECT d_year
#              ,i_brand_id
#              ,i_class_id
#              ,i_category_id
#              ,i_manufact_id
#              ,ss_quantity - COALESCE(sr_return_quantity,0) AS sales_cnt
#              ,ss_ext_sales_price - COALESCE(sr_return_amt,0.0) AS sales_amt
#        FROM store_sales JOIN item ON i_item_sk=ss_item_sk
#                         JOIN date_dim ON d_date_sk=ss_sold_date_sk
#                         LEFT JOIN store_returns ON (ss_ticket_number=sr_ticket_number
#                                                 AND ss_item_sk=sr_item_sk)
#        WHERE i_category='Electronics'
#        UNION DISTINCT
#        SELECT d_year
#              ,i_brand_id
#              ,i_class_id
#              ,i_category_id
#              ,i_manufact_id
#              ,ws_quantity - COALESCE(wr_return_quantity,0) AS sales_cnt
#              ,ws_ext_sales_price - COALESCE(wr_return_amt,0.0) AS sales_amt
#        FROM web_sales JOIN item ON i_item_sk=ws_item_sk
#                       JOIN date_dim ON d_date_sk=ws_sold_date_sk
#                       LEFT JOIN web_returns ON (ws_order_number=wr_order_number
#                                             AND ws_item_sk=wr_item_sk)
#        WHERE i_category='Electronics') sales_detail
#  GROUP BY d_year, i_brand_id, i_class_id, i_category_id, i_manufact_id)
#  SELECT  prev_yr.d_year AS prev_year
#                           ,curr_yr.d_year AS year
#                           ,curr_yr.i_brand_id
#                           ,curr_yr.i_class_id
#                           ,curr_yr.i_category_id
#                           ,curr_yr.i_manufact_id
#                           ,prev_yr.sales_cnt AS prev_yr_cnt
#                           ,curr_yr.sales_cnt AS curr_yr_cnt
#                           ,curr_yr.sales_cnt-prev_yr.sales_cnt AS sales_cnt_diff
#                           ,curr_yr.sales_amt-prev_yr.sales_amt AS sales_amt_diff
#  FROM all_sales curr_yr, all_sales prev_yr
#  WHERE curr_yr.i_brand_id=prev_yr.i_brand_id
#    AND curr_yr.i_class_id=prev_yr.i_class_id
#    AND curr_yr.i_category_id=prev_yr.i_category_id
#    AND curr_yr.i_manufact_id=prev_yr.i_manufact_id
#    AND curr_yr.d_year=2001
#    AND prev_yr.d_year=2001-1
#    AND CAST(curr_yr.sales_cnt AS FLOAT64)/CAST(prev_yr.sales_cnt AS FLOAT64)<0.9
#  ORDER BY
#   sales_cnt_diff nulls last,
#   sales_amt_diff nulls last
#  limit 100;
#
#
#
#
# Query ID: cb3626a8-e050-42ed-b2eb-9e4454a7083c
# Total Time Elapsed: 0 days 00:00:05.223953
# ----------------------------------------
#
#
# ========================================
# BigQuery Query Stream Done!
# Total Time Elapsed: 0 days 00:00:05.230929

# %%
df_sf = a.result_sf
df_bq = a.result_bq

# %%
df_sf.dtypes
# Out:
# PREV_YEAR           int16
# YEAR                int16
# I_BRAND_ID          int32
# I_CLASS_ID           int8
# I_CATEGORY_ID        int8
# I_MANUFACT_ID       int16
# PREV_YR_CNT         int64
# CURR_YR_CNT         int64
# SALES_CNT_DIFF      int64
# SALES_AMT_DIFF    float64
# dtype: object

# %%
df_bq.dtypes
# Out:
# prev_year           int64
# year                int64
# i_brand_id          int64
# i_class_id          int64
# i_category_id       int64
# i_manufact_id       int64
# prev_yr_cnt         int64
# curr_yr_cnt         int64
# sales_cnt_diff      int64
# sales_amt_diff    float64
# dtype: object

# %%
df_sf = tools.to_consistent(df_sf, n=5)
df_bq = tools.to_consistent(df_bq, n=5)

# %%
qc.assert_equal(df_sf, df_bq)
# Out:
# True

# %%
def color_false(val):
    mapper = {True: 'white', False: 'red'}
    return 'color: %s' % mapper[val]

# %%
diff = df_sf.eq(df_bq)
diff.loc[0:5].style.applymap(color_false)
# Out:
# <style  type="text/css" >
#     #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col0 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col1 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col2 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col3 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col4 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col5 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col6 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col7 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col8 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col9 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row1_col0 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row1_col1 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row1_col2 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row1_col3 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row1_col4 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row1_col5 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row1_col6 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row1_col7 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row1_col8 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row1_col9 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row2_col0 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row2_col1 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row2_col2 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row2_col3 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row2_col4 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row2_col5 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row2_col6 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row2_col7 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row2_col8 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row2_col9 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row3_col0 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row3_col1 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row3_col2 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row3_col3 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row3_col4 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row3_col5 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row3_col6 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row3_col7 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row3_col8 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row3_col9 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row4_col0 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row4_col1 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row4_col2 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row4_col3 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row4_col4 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row4_col5 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row4_col6 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row4_col7 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row4_col8 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row4_col9 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row5_col0 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row5_col1 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row5_col2 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row5_col3 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row5_col4 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row5_col5 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row5_col6 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row5_col7 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row5_col8 {
#             color:  white;
#         }    #T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row5_col9 {
#             color:  white;
#         }</style><table id="T_6166de7c_c26a_11ea_aed1_9cb6d0c46813" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >prev_year</th>        <th class="col_heading level0 col1" >year</th>        <th class="col_heading level0 col2" >i_brand_id</th>        <th class="col_heading level0 col3" >i_class_id</th>        <th class="col_heading level0 col4" >i_category_id</th>        <th class="col_heading level0 col5" >i_manufact_id</th>        <th class="col_heading level0 col6" >prev_yr_cnt</th>        <th class="col_heading level0 col7" >curr_yr_cnt</th>        <th class="col_heading level0 col8" >sales_cnt_diff</th>        <th class="col_heading level0 col9" >sales_amt_diff</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6166de7c_c26a_11ea_aed1_9cb6d0c46813level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col0" class="data row0 col0" >True</td>
#                         <td id="T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col1" class="data row0 col1" >True</td>
#                         <td id="T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col2" class="data row0 col2" >True</td>
#                         <td id="T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col3" class="data row0 col3" >True</td>
#                         <td id="T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col4" class="data row0 col4" >True</td>
#                         <td id="T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col5" class="data row0 col5" >True</td>
#                         <td id="T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col6" class="data row0 col6" >True</td>
#                         <td id="T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col7" class="data row0 col7" >True</td>
#                         <td id="T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col8" class="data row0 col8" >True</td>
#                         <td id="T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row0_col9" class="data row0 col9" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_6166de7c_c26a_11ea_aed1_9cb6d0c46813level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row1_col0" class="data row1 col0" >True</td>
#                         <td id="T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row1_col1" class="data row1 col1" >True</td>
#                         <td id="T_6166de7c_c26a_11ea_aed1_9cb6d0c46813row1_col2" cla

# %%
df_diff = diff.sum().sum() / (diff.shape[0] * diff.shape[1])
print("Percent Data Match:", df_diff)
# Out:
# Percent Data Match: 1.0

# %%
diff.sum()/diff.shape[0]
# Out:
# prev_year         1.0
# year              1.0
# i_brand_id        1.0
# i_class_id        1.0
# i_category_id     1.0
# i_manufact_id     1.0
# prev_yr_cnt       1.0
# curr_yr_cnt       1.0
# sales_cnt_diff    1.0
# sales_amt_diff    1.0
# dtype: float64

# %%
diff.style.applymap(color_false)
# Out:
# <style  type="text/css" >
#     #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row0_col0 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row0_col1 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row0_col2 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row0_col3 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row0_col4 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row0_col5 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row0_col6 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row0_col7 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row0_col8 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row0_col9 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row1_col0 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row1_col1 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row1_col2 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row1_col3 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row1_col4 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row1_col5 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row1_col6 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row1_col7 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row1_col8 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row1_col9 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row2_col0 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row2_col1 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row2_col2 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row2_col3 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row2_col4 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row2_col5 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row2_col6 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row2_col7 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row2_col8 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row2_col9 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row3_col0 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row3_col1 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row3_col2 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row3_col3 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row3_col4 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row3_col5 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row3_col6 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row3_col7 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row3_col8 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row3_col9 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row4_col0 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row4_col1 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row4_col2 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row4_col3 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row4_col4 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row4_col5 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row4_col6 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row4_col7 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row4_col8 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row4_col9 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row5_col0 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row5_col1 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row5_col2 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row5_col3 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row5_col4 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row5_col5 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row5_col6 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row5_col7 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row5_col8 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row5_col9 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row6_col0 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row6_col1 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row6_col2 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row6_col3 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row6_col4 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row6_col5 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row6_col6 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row6_col7 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row6_col8 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row6_col9 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row7_col0 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row7_col1 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row7_col2 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row7_col3 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row7_col4 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row7_col5 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row7_col6 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row7_col7 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row7_col8 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row7_col9 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row8_col0 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row8_col1 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row8_col2 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row8_col3 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row8_col4 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row8_col5 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row8_col6 {
#             color:  white;
#         }    #T_618096dc_c26a_11ea_aed1_9cb6d0c46813row8_col7 {
